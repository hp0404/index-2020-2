# %%
import pandas as pd
from custom_func import *

# %%
df_P05_005 = pd.read_excel(f"{INPUTS_PATH}/P5/P05_005.xlsx", dtype={"Код ЄДРПОУ": str})
agg_columns = [
    "Загальна площа земель лісового фонду, га", 
    "Площа земель лісового фонду, на які оформлені правовстановлюючі документи, га",
    "Обсяги виявлених незаконних рубок, м.куб."
]

df_P05_005_fin = df_P05_005.groupby("region", as_index=False)[agg_columns].sum()

df_P05_005_fin["частка незаконних рубок"] = (
    df_P05_005_fin["Обсяги виявлених незаконних рубок, м.куб."] / df_P05_005_fin["Загальна площа земель лісового фонду, га"]
)

df_P05_005_fin = df_P05_005_fin.rename(columns={'Обсяги виявлених незаконних рубок, м.куб.':'p5_01_raw'})

df_P05_005_fin["p5_02_raw"] = (
    df_P05_005_fin["Площа земель лісового фонду, на які оформлені правовстановлюючі документи, га"] / df_P05_005_fin["Загальна площа земель лісового фонду, га"]
)

normalize_parameter(df_P05_005_fin, "p5_01_raw", "p5_01")
normalize_parameter(df_P05_005_fin, "p5_02_raw", "p5_02",min_bound=0,max_bound=1)
# Out:
# Емпіричні границі: (52.494, 29748.138)
# Коефіцієнти нормалізації: (3.3674972666024685e-05, -0.0017677340151302998)
# Параметр p5_01 нормалізовано і додано до таблиці
#
# Емпіричні границі: (0, 1)
# Коефіцієнти нормалізації: (1.0, -0.0)
# Параметр p5_02 нормалізовано і додано до таблиці

# %%
df_P05_005_fin
# Out:
#                region  Загальна площа земель лісового фонду, га  \
# 0   Івано-Франківська                              4.562397e+05
# 1           Волинська                              6.187155e+05
# 2           Вінницька                              2.192930e+05
# 3    Дніпропетровська                              1.151240e+05
# 4            Донецька                              7.711400e+04
# 5         Житомирська                              1.083668e+06
# 6        Закарпатська                              5.887704e+05
# 7          Запорізька                              7.684100e+04
# 8            Київська                              7.246929e+05
# 9      Кіровогрдаська                              1.301207e+05
# 10          Луганська                              2.383208e+05
# 11          Львівська                              4.780210e+05
# 12       Миколаївська                              8.436169e+04
# 13         Полтавська                              2.357580e+05
# 14         Рівненська                              7.617564e+05
# 15            Сумська                              2.854350e+05
# 16      Тернопільська                              1.590790e+05
# 17         Харківська                              3.014120e+05
# 18         Херсонська                              1.742598e+05
# 19        Хмельницька                              1.935210e+05
# 20          Черкаська                              2.799329e+05
# 21        Чернівецька                              2.422880e+05
# 22       Чернігівська                              4.179201e+05
#
#     Площа земель лісового фонду, на які оформлені правовстановлюючі документи, га  \
# 0                                        5.361300e+04
# 1                                        3.409906e+05
# 2                                        2.098950e+05
# 3                                        2.507400e+04
# 4                                        1.098871e+04
# 5                                        1.439090e+06
# 6                                        3.228765e+05
# 7                                        2.069200e+04
# 8                                        4.502912e+05
# 9                                        3.452981e+04
# 10                                       7.938522e+04
# 11                                       1.020371e+05
# 12                                       3.043274e+04
# 13                                       6.440700e+04
# 14                                       7.244603e+05
# 15                                       2.567520e+05
# 16                                       3.867600e+04
# 17                                       4.918046e+03
# 18                                       4.565848e+04
# 19                                       1.907900e+05
# 20                                       1.796769e+05
# 21                                       6.777900e+04
# 22                                       4.164582e+05
#
#     p5_01_raw  частка незаконних рубок  p5_02_raw     p5_01     p5_02
# 0     429.650                 0.000942   0.117511  0.012701  0.117511
# 1     598.000                 0.000967   0.551127  0.018370  0.551127
# 2     157.800                 0.000720   0.957144  0.003546  0.957144
# 3    1267.000                 0.011006   0.217800  0.040898  0.217800
# 4     105.400                 0.001367   0.142500  0.001782  0.142500
# 5    5633.740                 0.005199   1.327981  0.187948  1.327981
# 6    1672.000                 0.002840   0.548391  0.054537  0.548391
# 7     214.500                 0.002791   0.269283  0.005456  0.269283
# 8     777.490                 0.001073   0.621355  0.024414  0.621355
# 9     125.000                 0.000961   0.265368  0.002442  0.265368
# 10    215.340                 0.000904   0.333102  0.005484  0.333102
# 11    778.000                 0.001628   0.213457  0.024431  0.213457
# 12    185.290                 0.002196   0.360741  0.004472  0.360741
# 13    242.600                 0.001029   0.273191  0.006402  0.273191
# 14    434.000                 0.000570   0.951039  0.012847  0.951039
# 15     99.590                 0.000349   0.899511  0.001586  0.899511
# 16    231.000                 0.001452   0.243124  0.006011  0.243124
# 17  29748.138                 0.098696   0.016317  1.000000  0.016317
# 18   1026.667                 0.005892   0.262014  0.032805  0.262014
# 19    126.000                 0.000651   0.985888  0.002475  0.985888
# 20    114.200                 0.000408   0.641857  0.002078  0.641857
# 21    223.900                 0.000924   0.279746  0.005772  0.279746
# 22     52.494                 0.000126   0.996502  0.000000  0.996502

# %%
#Група 1: p5_01-p5_02, незаконні вирубки
#Група 2: p5_03, природно-заповідний фонд
#Група 3: p5_06, альтернативна енергетика
dict_weights = {
    'p5_01':0.5,
    'p5_02':0.5,
    'p5_03':1,
    'p5_06':1
}

sources = [df_P05_005_fin]
save_data(sources,regions,dict_weights,'P5')
# Out:
# Дані за галузевим параметром P5 збережено
#                region     p5_01     p5_02        P5
# 0           Волинська  0.018370  0.551127  0.949161
# 1           Вінницька  0.003546  0.957144  1.601150
# 2    Дніпропетровська  0.040898  0.217800  0.431164
# 3            Донецька  0.001782  0.142500  0.240469
# 4         Житомирська  0.187948  1.327981  2.526549
# 5        Закарпатська  0.054537  0.548391  1.004880
# 6          Запорізька  0.005456  0.269283  0.457898
# 7            Київська  0.024414  0.621355  1.076281
# 8   Івано-Франківська  0.012701  0.117511  0.217019
# 9      Кіровоградська  0.000000  0.000000  0.000000
# 10          Луганська  0.005484  0.333102  0.564310
# 11          Львівська  0.024431  0.213457  0.396481
# 12       Миколаївська  0.004472  0.360741  0.608689
# 13            Одеська  0.000000  0.000000  0.000000
# 14         Полтавська  0.006402  0.273191  0.465988
# 15         Рівненська  0.012847  0.951039  1.606477
# 16            Сумська  0.001586  0.899511  1.501829
# 17      Тернопільська  0.006011  0.243124  0.415226
# 18         Харківська  1.000000  0.016317  1.693861
# 19         Херсонська  0.032805  0.262014  0.491365
# 20        Хмельницька  0.002475  0.985888  1.647272
# 21          Черкаська  0.002078  0.641857  1.073225
# 22        Чернівецька  0.005772  0.279746  0.475863
# 23       Чернігівська  0.000000  0.996502  1.660837
# 24     Кіровогрдаська  0.002442  0.265368  0.446349
